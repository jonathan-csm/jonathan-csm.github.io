# %% [markdown]
# <a href="https://colab.research.google.com/github/jonathan-csm/jonathan-csm.github.io/blob/main/jonathan_first_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Jonathan Ignatius Saldanha"
grade = 10
location = "Dubai, United Arab Emirates"

print("---------------------------------")
print("Developer Profile:", name)
print("Current Status: Grade",grade," and I study in", location)
print("Status: Working towards creating a portfolio for myself!")
print("---------------------------------")
# Out:
# ---------------------------------
# Developer Profile: Jonathan Ignatius Saldanha
# Current Status: Grade 10  and I study in Dubai, United Arab Emirates
# Status: Working towards creating a portfolio for myself!
# ---------------------------------
